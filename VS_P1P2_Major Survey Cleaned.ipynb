# %% [markdown]
# ## Vaishna Subbaiah

# %% [markdown]
# ### 10/10/25

# %% [markdown]
# ##### Objective: Explore the Project 1 dataset using Python, and perform data cleaning using pandas.

# %% [markdown]
# #### import pandas

# %%
import pandas as pd

# %% [markdown]
# #### read in file

# %%
#Load data 
df = pd.read_csv("Majors Survey Results - Fall 2024.csv")

# %% [markdown]
# #### describes data

# %%
df.describe()
# Out:
#        On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?
# count                                          62.000000
# mean                                            3.580645
# std                                             1.079593
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000

# %% [markdown]
# #### returns columns

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %% [markdown]
# #### returns shape (width/length)

# %%
df.shape
# Out:
# (197, 90)

# %% [markdown]
# #### returns all data types

# %%
df.dtypes
# Out:
# Timestamp                                                                                                                                               object
# Which course are you enrolled in?                                                                                                                       object
# How did you hear about County College of Morris? [CCM Web site]                                                                                         object
# How did you hear about County College of Morris? [Social Media]                                                                                         object
# How did you hear about County College of Morris? [Community Event]                                                                                      object
#                                                                                                                                                         ...
# ...

# %% [markdown]
# #### returns top rows of the data set

# %%
df.head()
# Out:
#                     Timestamp Which course are you enrolled in?  \
# 0  2024/09/09 12:33:58 PM AST        CMP 128 Computer Science I
# 1   2024/09/09 6:00:11 PM AST                               NaN
# 2   2024/09/10 9:00:12 AM AST        CMP 128 Computer Science I
# 3  2024/09/10 12:34:53 PM AST        CMP 128 Computer Science I
# 4   2024/09/10 3:06:47 PM AST        CMP 128 Computer Science I
#
#   How did you hear about County College of Morris? [CCM Web site]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   How did you hear about County College of Morris? [Social Media]  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# ...

# %% [markdown]
# #### returns bottoms rows of the data set

# %%
df.tail()
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 192                                       Don't recall
# 193                                                Yes
# 194                                                Yes
# 195                                                Yes
# 196                                                 No
#
#     How did you hear about County College of Morris? [Social Media]  \
# 192                                       Don't recall
# ...

# %% [markdown]
# #### runs a sample of items

# %%
df.sample()
# Out:
#                       Timestamp             Which course are you enrolled in?  \
# 143  2024/09/13 11:59:56 AM AST  CMP 131 Fundamentals of Programming (Python)
#
#     How did you hear about County College of Morris? [CCM Web site]  \
# 143                                                 No
#
#     How did you hear about County College of Morris? [Social Media]  \
# 143                                                 No
#
#     How did you hear about County College of Morris? [Community Event]  \
# 143                                                Yes
#
#     How did you hear about County College of Morris? [Family member or friend]  \
# 143                                                Yes
#
#     How did you hear about County College of Morris? [Current CCM student]  \
# 143                                                Yes
#
#     How did you hear about County College of Morris? [CCM Alumni]  \
# 143                                                 No
#
# ...

# %% [markdown]
# #### returns summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 90 columns):
#  #   Column                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                           --------------  -----
#  0   Timestamp                                                                                                                                                                                                                                                        197 non-null    object
# ...

# %%
df.columns #printing columns again - just to check
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### renaming column names using keys and values

# %%
rename_map = {
     # --- Miscellaneous ---
    'Gender': 'gender',
    'Race/ethnicity': 'race_ethnicity',
    'Age ': 'age',
    'Which course are you enrolled in?' : 'course',
    'Timestamp' : 'timestamp',
    
    # --- How did you hear about CCM ---
    'How did you hear about County College of Morris? [CCM Web site]': 'ccm_website',
    'How did you hear about County College of Morris? [Social Media]': 'social_media',
    'How did you hear about County College of Morris? [Community Event]': 'community_event',
    'How did you hear about County College of Morris? [Family member or friend]': 'relative',
    'How did you hear about County College of Morris? [Current CCM student]': 'ccm_student',
    'How did you hear about County College of Morris? [CCM Alumni]': 'ccm_alumni',
    'How did you hear about County College of Morris? [High School Teacher]': 'hs_teacher',
    'How did you hear about County College of Morris? [High School Counselor]': 'hs_counselor',
    'How did you hear about County College of Morris? [In-app advertisement]': 'inapp_ad',
    'How did you hear about County College of Morris? [Employer]': 'employer',
    'How did you hear about County College of Morris? [Billboard]': 'billboard',
    'How did you hear about County College of Morris? [Television]': 'tv',
    'How did you hear about County College of Morris? [Radio]': 'radio',
    'How did you hear about County College of Morris? [Other]': 'other',

    # --- Impact factors ---
    'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]': 'affordability',
    'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]': 'location',
    'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]': 'program_choice',
    'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]': 'online_offerings',
    'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]': 'relative_referral',
    'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]': 'faculty_staff',
    'To what extent did the following impact your decision to attend County College of Morris? [College reputation]': 'reputation',
    'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]': 'financial_aid',
    'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]': 'scholarships',
    'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]': 'small_classes',
    'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]': 'ecs',
    'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]': 'transfer_credits',
    'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]': 'negative_other_college',
    'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]': 'nj_stars',
    'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]': 'transferability',
    'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]': 'hs_credit',

    # --- Prior to applying / participation ---
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Open House]': 'participate_open_house',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Instant Decision Day]': 'instant_decision',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [On-Campus Information Session]': 'info_session',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Titans Tuesday (Virtual) Information Session]': 'titans_tuesday',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Women Who Dare]': 'women_who_dare',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Regional College Fair]': 'college_fair',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [HS Sharetime Information Session]': 'hs_sharetime',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Challenger Program]': 'challenger',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [CyberSecurity Information Protection Program Participation ]': 'cybersecurity',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Information Session at my high school]': 'hs_info_session',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit with my high school]': 'hs_visit',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Campus Visit (individual)]': 'individual_visit',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Workforce Development class]': 'workforce_class',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Corporate Training]': 'corporate_training',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Teen Arts Festival]': 'teen_arts',
    'Prior to applying to college, did you participate in any of the following events or activities at the County College of Morris and/or with the Department of Information Technologies, if at all? [Summer camp at CCM]': 'summer_camp',

    # --- Computing influences ---
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing class]': 'influence_hs_class',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Middle/High school computing related club]': 's_club',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Computing-related competitions (e.g., Robotics competition, Lego competition, Cybersecurity, Programming)]': 'competitions',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Afterschool computing-related camp/program]': 'afterschool_camp',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Summer computing related camp/program]': 'summer_camp',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [An AP computing class]': 'ap_class',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [A dual enrollment computing class]': 'dual_enroll',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend influence]': 'family_friend',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Family or friend working in the computing field]': 'relative_in_field',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [High school teacher or guidance counselor]': 'hs_teacher_counselor',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Employer influence]': 'employer',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Current CCM student]': 'influence_ccm_student',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Experience at work]': 'work_experience',
    'To what extent did the following activities or experience impact your decision to enroll in an computing course at CCM? [Other]': 'other',

    # --- Motivation ---
    'What degree program are you currently enrolled in?': 'degree_program',
    'What motivated you to seek a computing degree/certificate at CCM?  [To get a job in the computing field]': 'motivation_job',
    'What motivated you to seek a computing degree/certificate at CCM?  [Transfer to bachelor\'s level program]': 'motivation_transfer',
    'What motivated you to seek a computing degree/certificate at CCM?  [Transfer credits back to HS degree (ShareTime, Challenger Program)]': 'hs_motivation_transfer',
    'What motivated you to seek a computing degree/certificate at CCM?  [Career Advancement]': 'career_advancement',
    'What motivated you to seek a computing degree/certificate at CCM?  [Career Change]': 'career_change',
    'What motivated you to seek a computing degree/certificate at CCM?  [Professional Development]': 'professional_dev',
    'What motivated you to seek a computing degree/certificate at CCM?  [Job Displacement]': 'job_displacement',
    'What motivated you to seek a computing degree/certificate at CCM?  [Relocation]': 'relocation',
    'What motivated you to seek a computing degree/certificate at CCM?  [To keep current in tech industry]': 'keep_current',
    'What motivated you to seek a computing degree/certificate at CCM?  [IT Industry Certifications]': 'certifications',
    'What motivated you to seek a computing degree/certificate at CCM?  [Financial]': 'financial',
    'What motivated you to seek a computing degree/certificate at CCM?  [Personal Enrichment]': 'enrichment',

    # --- Information sources ---
    'Did you receive information about the CCM computing programs from any of the following sources? [High school guidance counselor]': 'info_hs_counselor',
    'Did you receive information about the CCM computing programs from any of the following sources? [High School Teacher]': 'hs_teacher',
    'Did you receive information about the CCM computing programs from any of the following sources? [CCM Information Technologies Website]': 'it_website',
    'Did you receive information about the CCM computing programs from any of the following sources? [CCM Admissions]': 'admissions',
    'Did you receive information about the CCM computing programs from any of the following sources? [CCM advisor/counselor]': 'ccm_advisor',
    'Did you receive information about the CCM computing programs from any of the following sources? [Employer]': 'employer',
    'Did you receive information about the CCM computing programs from any of the following sources? [CCM Workforce Development]': 'workforce_dev',
    'Did you receive information about the CCM computing programs from any of the following sources? [NJ Workforce Development Program]': 'nj_workforce',
    'Did you receive information about the CCM computing programs from any of the following sources? [Other]': 'other',

}

# Apply the renaming
df.rename(columns=rename_map, inplace=True)

# %% [markdown]
# #### prints the new/updated column names

# %%
df.columns
# Out:
# Index(['timestamp', 'course', 'ccm_website', 'social_media', 'community_event',
#        'relative', 'ccm_student', 'ccm_alumni', 'hs_teacher', 'hs_counselor',
#        'inapp_ad', 'employer', 'billboard', 'tv', 'radio', 'other',
#        'affordability', 'location', 'program_choice', 'online_offerings',
#        'relative_referral', 'faculty_staff', 'reputation', 'financial_aid',
#        'scholarships', 'small_classes', 'ecs', 'transfer_credits',
#        'negative_other_college', 'nj_stars', 'transferability', 'hs_credit',
#        'participate_open_house', 'instant_decision', 'info_session',
#        'titans_tuesday', 'women_who_dare', 'college_fair', 'hs_sharetime',
#        'challenger', 'cybersecurity', 'hs_info_session', 'hs_visit',
#        'individual_visit', 'workforce_class', 'corporate_training',
#        'teen_arts', 'summer_camp', 'influence_hs_class', 's_club',
#        'competitions', 'afterschool_camp', 'summer_camp', 'ap_class',
# ...

# %% [markdown]
# #### get rid of unecessary columns

# %%
df.drop(columns=[
    'Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.',
       'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?',
       'Please explain your answer to the question above.  Why or why not would you be interested in taking another computing class?'
], inplace=True)

# %%
df.columns
# Out:
# Index(['timestamp', 'course', 'ccm_website', 'social_media', 'community_event',
#        'relative', 'ccm_student', 'ccm_alumni', 'hs_teacher', 'hs_counselor',
#        'inapp_ad', 'employer', 'billboard', 'tv', 'radio', 'other',
#        'affordability', 'location', 'program_choice', 'online_offerings',
#        'relative_referral', 'faculty_staff', 'reputation', 'financial_aid',
#        'scholarships', 'small_classes', 'ecs', 'transfer_credits',
#        'negative_other_college', 'nj_stars', 'transferability', 'hs_credit',
#        'participate_open_house', 'instant_decision', 'info_session',
#        'titans_tuesday', 'women_who_dare', 'college_fair', 'hs_sharetime',
#        'challenger', 'cybersecurity', 'hs_info_session', 'hs_visit',
#        'individual_visit', 'workforce_class', 'corporate_training',
#        'teen_arts', 'summer_camp', 'influence_hs_class', 's_club',
#        'competitions', 'afterschool_camp', 'summer_camp', 'ap_class',
# ...

# %% [markdown]
# #### returns top rows of updated dataset

# %%
df.head()
# Out:
#                     timestamp                      course ccm_website  \
# 0  2024/09/09 12:33:58 PM AST  CMP 128 Computer Science I         Yes
# 1   2024/09/09 6:00:11 PM AST                         NaN          No
# 2   2024/09/10 9:00:12 AM AST  CMP 128 Computer Science I          No
# 3  2024/09/10 12:34:53 PM AST  CMP 128 Computer Science I         Yes
# 4   2024/09/10 3:06:47 PM AST  CMP 128 Computer Science I          No
#
#   social_media community_event relative ccm_student ccm_alumni hs_teacher  \
# 0          Yes             Yes      Yes         Yes        Yes        Yes
# 1           No             Yes       No          No         No        Yes
# 2           No              No      Yes          No        Yes         No
# 3          Yes             Yes      Yes          No         No        Yes
# 4           No              No      Yes          No         No        Yes
#
#    hs_counselor  ... it_website admissions ccm_advisor employer workforce_dev  \
# ...

# %% [markdown]
# #### returns bottoms rows of updated dataset

# %%
df.tail()
# Out:
#                       timestamp                                        course  \
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
#       ccm_website  social_media community_event      relative ccm_student  \
# 192  Don't recall  Don't recall    Don't recall  Don't recall         Yes
# 193           Yes            No              No           Yes          No
# 194           Yes  Don't recall              No            No          No
# 195           Yes            No              No           Yes         Yes
# 196            No            No              No           Yes         Yes
#
# ...

# %% [markdown]
# #### returns the whole dataset

# %%
df
# Out:
#                       timestamp                                        course  \
# 0    2024/09/09 12:33:58 PM AST                    CMP 128 Computer Science I
# 1     2024/09/09 6:00:11 PM AST                                           NaN
# 2     2024/09/10 9:00:12 AM AST                    CMP 128 Computer Science I
# 3    2024/09/10 12:34:53 PM AST                    CMP 128 Computer Science I
# 4     2024/09/10 3:06:47 PM AST                    CMP 128 Computer Science I
# ..                          ...                                           ...
# 192   2024/09/22 6:32:46 PM AST                    CMP 128 Computer Science I
# 193   2024/09/22 8:51:18 PM AST                    CMP 128 Computer Science I
# 194   2024/09/22 9:17:23 PM AST                    CMP 128 Computer Science I
# 195  2024/09/22 11:07:28 PM AST                    CMP 128 Computer Science I
# 196   2024/09/27 1:01:23 PM AST  CMP 131 Fundamentals of Programming (Python)
#
# ...

# %% [markdown]
# #### save dataset to a CSV file

# %%
df.to_csv("cleaned_majors_survey.csv", index=False)

# %% [markdown]
# #### Citations: For this project, I used the assistance of ChatGPT, the Anaconda Assistance, and my peers (Caitlyn and Mitra) to create code segments, as there would be faulty code at times
